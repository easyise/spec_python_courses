# %% [markdown]
# ## Программирование на Python. Начальный уровень.
#
# ### Занятие 10. Практика и контрольная работа
#
# Ниже приведены 5 задач. Решите их самостоятельно, используя знания, полученные в рамках этого курса. Можно (и нужно) использовать тетрадки и примеры кода оттуда.
#
# Время на выполнение задания - 1 час.
#
# После выполнения будет разбор задач с преподавателем.

# %% [markdown]
# 1. Решите несколько простейших задач

# %%
hello = "Hello"

# выведите строку hello на экран

# выведите строку hello на экран 5 раз одной строкой

# выведите строку hello на экран 5 раз, друг под другом

# выведите строку hello на экран 5 раз в столбик, с номерами строк

# сделайте так, чтобы все буквы в строке hello задвоились

# инвертируйте строку (напишите задом наперед)

# выведите уникальные символы (без учета регистра), содержащиеся в строке, в алфавитном порядке

# %% [markdown]
# 2. Решите несколько небольших задач:
#
# _решение этих задач в одну строку - крайне приветствуется_

# %%
import random

# создайте два списка целых случайных чисел в диапазоне от 0 до N включительно, длиной N
# используйте функцию random.randint(0,N)


# найдите все элементы, которые содержатся как в одном, так и в другом списке. Если таковых нет - выведите "NO"
# используйте множества

# %%
## проверьте, является ли строка палиндромом
# используйте срезы
str1 = "abba"

# %%
## извлеките из данной строки все цифры в новую строку
str2 = "2h29we3hask45qq17"
# ваш код здесь

# %% [markdown]
# 3. Для заданного списка напишите функцию, которая будет выполнять в нем циклические перестановки. То есть последний элемент будет вставляться на место первого, сдвигая остальной список вправо. Пользоваться удалением и вставкой в списки нельзя.

# %%
list_ = [7, 9, 2, 1]

def rotate_list( list_ ):
    # ваш код здесь
    

for i in range(5):
    print(list_) # [1, 7, 9, 2]
    rotate_list(list_)

# %% [markdown]
# 4. Запросите у пользователя ввод текстовой строки, затем ввод двух чисел: количество колонок и строк, в которые нужно будет поместить введенную строку в последовательности сверху вниз, справа налево. Программа должна будет вывести текст именно в таком виде. Если строка не занимает пространство полностью, заполните пропуски символом "-". Пробелы тоже надо заменять на "-". Если строка не влезает в пространство - ее нужно будет обрезать.
#
# Пример:
# ```
# Введите строку: hello world
# Столбцов: 4
# Строк: 5
#
# Результат:
# h-d-
# ew--
# lo--
# lr--
# ol--
# ```

# %%
str1 = "hello world"
cols =  4
rows = 5
# ваш код здесь

# %% [markdown]
# 5. Упорядочьте заданный текст по убыванию дат:

# %%
import re

str_rex = r"(?P<month>[0-3]?[0-9])\/(?P<day>[0-9]{1,2})\/(?P<year>[0-9]{4})"
rex = re.compile(str_rex)

text = \
"""
День Рождения Пушкина А.С.: 05/26/1799
Запуск первого искусственого спутника Земли: 10/07/1957
Основание Москвы: 09/01/1147
День смерти Высоцкого: 07/25/1980
Основание Санкт-Петербурга: 05/27/1703
Переход человека в гильбертово пространство: 07/03/2068
День Рождения Исаака Ньютона: 01/04/1643
Полет человека в космос: 04/12/1961
Наступление Всемирной Сингулярности: 12/12/2068
"""

# ваш код здесь
