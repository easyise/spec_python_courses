# %% [markdown]
# # Курс "Программирование на языке Python. Уровень 4. Анализ и визуализация данных на языке Python. Библиотеки numpy, pandas, matplotlib"
#
# ## Домашнее задание, практика по numpy и pandas
#
# Выполните следующие задачи. __ВНИМАНИЕ__: пользоваться циклами нельзя (если в условиях задачи не указано обратное).

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# 1. Получите массив numpy, состоящий только из четных чисел в диапазоне от -100 до 100, при этом:
# - положительные числа должны быть кратны 3
# - отрицательные числа должны быть кратны 5.

# %%
# ваш код здесь

# %% [markdown]
# 2. Создайте матрицу размера MxN, где M и N - случайные числа в диапазоне от 8 до 12-ти. Матрица должна быть заполнена целыми случайными числами в диапазоне от 0 до 10-ти (включая 10). Шкалируйте значения в матрице: приведите значения в вещественные числа в диапазоне от 0 до 1: минимальные значения должны превратиться в 0, максимальные - в 1.

# %%
np.random.seed(20240120)
# ваш код здесь

# %% [markdown]
# 3. Используя библиотеку ```numpy``` (не ```PIL```!), для изображения lena.jpg сформируйте негативное изображение "Лены" (максимальная яркость должна стать минимальной, и наоборот).

# %%
from PIL import Image
from PIL import ImageFilter
import os

lena = Image.open('lena.jpg')

a_lena = np.array(lena)

display(lena)
# ваш код здесь
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x256>

# %% [markdown]
# 4. Создайте ```pandas.DataFrame``` для матрицы со случайными целыми значениями размером 150х8, задайте для каждого из 8-ми признаков имена ```f1, f2, ..., f8```. Для данной таблицы получите ```DataFrame```, содержащий top 5 строк по суммам значений (вместе с суммами), упорядоченный по убыванию этих сумм.

# %%
np.random.seed(20240120)
# ваш код здесь

# %% [markdown]
# 5. Загрузите датасет [Web Traffic](https://github.com/easyise/spec_python_courses/raw/master/python04-analysis/data/web_traffic.tsv) (это tsv-файл, он как csv, только разделители там - символы табуляции ```\t```).  Посчитайте пропущенные значения. Примите решение, что с ними делать и сделайте это.

# %%
# ваш код здесь
